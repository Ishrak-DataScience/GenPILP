# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>2F0H-TAEW</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Ishrak1995</b> (token: <code>oauth-Ishrak1995</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
# !cd /content/drive/MyDrive/GenAI4Drug/Code/config.py
# Out:
# /bin/bash: line 1: cd: /content/drive/MyDrive/GenAI4Drug/Code/config.py: Not a directory

# %%
# !pip install torch transformers datasets rdkit pandas seaborn matplotlib selfies sympy chembl_webresource_client tqdm reportlab 'torchao>=0.16.0' peft  -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.0 MB/s eta 0:00:00

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage1_mask_calculation.py
# Out:
# ...
# STAGE 1: MASK CALCULATION
# ...
#
#   Masking mode:
#     1 : INTERACTION      (mask_non_attractive = False)  [default]
#         Atoms that DO participate in protein-ligand interactions
#         (hydrophobic, H-bond, pi-stacking, salt bridge, etc.) are masked.
#         ChemBERTa reconstructs the interacting atoms — generates molecules
#         with alternative binding groups, scaffold unchanged.
#
#     2 : NON-INTERACTION  (mask_non_attractive = True)
#         Atoms that do NOT participate in interactions are masked.
#         ChemBERTa reconstructs the non-interacting scaffold — generates
#         molecules with alternative scaffolds, binding pharmacophore unchanged.
#
#   Select masking mode (1 / 2) [1]: 2
#
#   ✅ Masking mode : NON-INTERACTION  (mask_non_attractive = True)
#   Non-interacting atoms will be masked.
#
#
#   Available ligands:
#      1 : JQ1_A_201         (pdb: /content/drive/MyDrive/GenAI4Drug/Dummy_data/PDB/4QZS)
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage1_5_random_masking.py
# Out:
# ...
# STAGE 1.5: RANDOM MASK GENERATION
# ...
#   Found 5 Stage-1 JSON(s) in /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/PLIP_Mask_Calculation/
#   ✅ 1GH-A-1173  →  19 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/Random_Mask_Calculation/1GH_A_1173_masked_1GH_A_1173.meta.random.json
#   ✅ 62G-A-201  →  16 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/Random_Mask_Calculation/62G_A_201_masked_62G_A_201.meta.random.json
#   ✅ EAM-A-1  →  22 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/Random_Mask_Calculation/EAM_A_1_masked_EAM_A_1.meta.random.json
#   ✅ JQ1-A-1  →  20 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/Random_Mask_Calculation/JQ1_A_1_masked_JQ1_A_1.meta.random.json
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code_v2/stage1_7_chembl_random_masking.py   # ~8000 ChEMBL molecules if cache is full
# Out:
# ...
# STAGE 1.7: ChEMBL BRD4 RANDOM MASK GENERATION
# ...
#
#   Reads BRD4-active molecules from:
#     /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo10/chembl_brd4_cache.csv
#   (fetches with pChEMBL ≥ 5.0 if cache missing)
#
#   Writes one random-mask JSON per molecule to:
#     /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo10/ChEMBL_Mask_Calculation/
#
#   ChEMBL mask fraction (0–1), or Enter for PDB-derived rate [7D]:
#   Mask fraction    : 0.6568  (PDB-derived (7D))
#   RNG seed         : 17
#   Using ChEMBL cache: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo10/chembl_brd4_cache.csv
#   7851 ChEMBL molecules after filter (RDKit-valid, ≥7 heavy atoms).
# ChEMBL masking:   0% 0/7851 [00:00<?, ?mol/s]
# config.json: 100% 501/501 [00:00<00:00, 931kB/s]
#
# tokenizer_config.json: 100% 166/166 [00:00<00:00, 955kB/s]
#
# vocab.json: 100% 9.43k/9.43k [00:00<00:00, 5.69MB/s]
#
# merges.txt: 100% 3.21k/3.21k [00:00<00:00, 10.2MB/s]
#
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage1_9_LLM_RDkit_policy_training.py
# Out:
# ...
# STAGE 1.9 — LLM RDKit POLICY TRAINING  (REINFORCE)
# ...
#
#   What this script does
#   ─────────────────────
#   1. Loads masked SMILES from Stage-1 (IA), Stage-1.5 (random), and
#      Stage-1.7 (ChEMBL BRD4 random) JSON files.
#   2. Loads ChemBERTa with trainable LoRA adapters (~1% of parameters).
#   3. For each masked SMILES (training sample):
#        a. Fills every <mask> token left-to-right, sampling from top-20.
#        b. Records log P(chosen_token | context) at each mask position.
#        c. Decodes the full SMILES and scores it with RDKit:
#             reward = 0.5·valid  +  0.3·QED  +  0.2·SA
#        d. Computes REINFORCE loss = −(reward − baseline) × Σ log_prob.
#        e. Updates LoRA weights via backprop.
#   4. After each epoch saves a checkpoint so training can be paused and
#      resumed at any time.
#
#   Hyper-parameters
#   ────────────────
#   LoRA rank      : 8   (target: ['query', 'value'])
#   Temperature    : 1.2     Top-k      : 20
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage2_token_ratio_plot.py

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage2_7_multi_seed_generation_with_progress_bar.py
# Out:
# ...
# STAGE 2.7: MULTI-SEED RANDOM-PICK GENERATION
# ...
#
#   Extends Stage 2.5 with multiple random seeds.
#
#   Seeds          : [17, 53, 89]
#   Stage-2.5 seed : 17  ← will reuse Stage-2.5 results if present
#
#   For each (seed, mask_count) cell:
#     step_seed = seed + mask_count
#     ia_picked = random.sample(ia_indices, mask_count)   [seeded]
#
#   Reuse order:
#     1. Stage-2.5 output  (if seed == 17 and files exist)
#     2. Stage-2.7 cache   (from a previous Stage-2.7 run)
#     3. Generate fresh
#
#   Aggregated outputs (union across all seeds per mask_count):
#     /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo11_fixed_BPE_tokenization/predictions_txt_multi_seed/
#
#   These are format-compatible with Stages 3–7.
#   Stage 2.5 is NOT required to have been run first.
#
#   Smoke test verifies reuse logic and aggregation — no GPU needed.
#
#   Run the smoke test? [y/N]: N
#   Run the full generation? (requires GPU + ChemBERTa) (yes/no): yes
#
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code_v2/stage3_analysis.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GenAI4Drug/Code_v2/stage3_analysis.py", line 79, in <module>
#     from rdkit import Chem
# ModuleNotFoundError: No module named 'rdkit'

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage5_chembl_matching.py
# Out:
# ...
# STAGE 5: ChEMBL BRD4 NEAREST-NEIGHBOUR MATCHING
# ...
#   Run the smoke test? [y/N]: N
#
# ────────────────────────────────────────────────────────────
# STAGE 5 OPTIONS
# ────────────────────────────────────────────────────────────
#
#   Cached ChEMBL data found at:
#     /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo07/stage5_chembl_matching/chembl_brd4_cache.csv
#   Use cached ChEMBL data (faster)? [Y/n]: Y
#
#   Pool choice — which generated molecules to analyse:
#     ia   : interaction-aware only  (Stage-1 masks)
#     rand : random only             (Stage-1.5 masks)
#     both : IA + random, deduplicated  [default]
#
#   Pool choice (ia / rand / both) [both]: both
#   Minimum heavy atoms for ChEMBL molecules (filters fragments) [7]:
#   Tanimoto similarity threshold T for 'close' decision (0.0–1.0) [0.4]:
#
#   Settings confirmed:
#     ChEMBL data    : cached  (/content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo07/stage5_chembl_matching/chembl_brd4_cache.csv)
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage4_1_brd4_matching.py
# Out:
# ────────────────────────────────────────────────────────────
# STAGE 4 OPTIONS
# ────────────────────────────────────────────────────────────
#
#   Pool choice — which generated molecules to analyse:
#     ia   : interaction-aware only  (Stage-1 masks)
#     rand : random only             (Stage-1.5 masks)
#     both : IA + random, deduplicated  [default]
#
#   Pool choice (ia / rand / both) [both]: ia
#   Minimum heavy atoms for BR4 ligands (filters solvents) [7]:
#   Similarity threshold T for 'close' decision (0.0–1.0) [0.4]: 0.42
#
#   Settings confirmed:
#     Pool              : ia
#     Min heavy atoms   : 7
#     Threshold T       : 0.42
# ────────────────────────────────────────────────────────────
#
# [14:07:57] SMILES Parse Error: syntax error while parsing: nan
# [14:07:57] SMILES Parse Error: check for mistakes around position 2:
# [14:07:57] nan
# [14:07:57] ~^
# [14:07:57] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# ...

# %%
##NO need to run
##!python /content/drive/MyDrive/GenAI4Drug/Code/stage5_1chembl_matching.py
# Out:
#   Use cached ChEMBL data? [Y/n]: Y
#   Pool choice (ia / rand / both) [both]: both
#   Minimum heavy atoms for ChEMBL molecules [7]:
#   Tanimoto similarity threshold T [0.4]: 0.42
#   Enter 1 (Stage 2), 2 (Stage 2.5), or 3 (Stage 2.7) [1]: 3

# %%
#check if GNINA is in full binary. If it has .ELFat end  everything is fine
# !head -c 4 /content/gnina | xxd
# Out:
# head: cannot open '/content/gnina' for reading: No such file or directory

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage6_docking.py
# Out:
# python3: can't open file '/content/drive/MyDrive/GenAI4Drug/Code/stage6_docking.py': [Errno 2] No such file or directory

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage8_3_novelty_potency_analysis.py
# Out:
# ...
# STAGE 8: NOVELTY vs POTENCY ANALYSIS
# ...
#
#   Reads docking_summary.csv from Stage 6 and produces:
#     • Scatter plots: Tanimoto (X) vs docking score (Y)
#         — one per ligand group + one combined
#     • Pareto front: non-dominated molecules (best novel + potent trade-offs)
#     • Hierarchical filter: CNNscore > T, Vinardo < T, sorted by CNNaffinity
#     • Top-10 PDF: Pareto-optimal molecules with drawing + all scores
#
#   config.STAGE8_INPUT_CSV = /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo07/stage6_docking/stage2.7/ia/docking_summary.csv
#   config.STAGE8_DIR       = /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo07/stage8_analysis/CompositeCNN/non_interacting_part_masked/
#
#   Smoke test uses synthetic data — no real docking required.
#
#   Run the smoke test? [y/N]: N
#   ✅ Using config CSV: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo07/stage6_docking/stage2.7/ia/docking_summary.csv
#
#   Available ligand groups in docking CSV:
# ...

# %%
NN
