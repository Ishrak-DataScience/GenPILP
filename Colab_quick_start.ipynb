# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd /content/drive/MyDrive/GenAI4Drug/Code

# %%
# !pip install torch transformers datasets rdkit pandas seaborn matplotlib selfies sympy chembl_webresource_client reportlab -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 63.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.1 MB/s eta 0:00:00

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/config.py

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage1_mask_calculation.py
# Out:
# ...
# STAGE 1: MASK CALCULATION
# ...
#
# → Processing JQ1_A_201
# SERIAL TO TYPES: {2164: {('hbond', 'acceptor')}, 2157: {'hydrophobic'}, 2151: {'hydrophobic'}, 2159: {'hydrophobic'}, 2149: {'hydrophobic'}, 2152: {'hydrophobic'}, 2153: {'hydrophobic'}, 2161: {'hydrophobic'}, 2158: {'hydrophobic'}, 2160: {'hydrophobic'}}
# [DEBUG] OpenBabel route failed: [Errno 2] No such file or directory: 'obabel'
# ...
# [14:41:18] WARNING: More than one matching pattern found - picking one
#
#   💾 JSON saved: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/PLIP_Mask_Calculation/JQ1_A_201_masked_JQ1_A_201.meta.json
#   🖼  Plot saved: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/PLIP_Mask_Calculation/JQ1_A_201_masked.2d_interactions.png
#
# → Processing JQ1_A_1
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage1_5_random_masking.py
# Out:
# ...
# STAGE 1.5: RANDOM MASK GENERATION
# ...
#   Found 5 Stage-1 JSON(s) in /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/PLIP_Mask_Calculation/
#   ✅ 1GH-A-1173  →  12 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/Random_Mask_Calculation/1GH_A_1173_masked_1GH_A_1173.meta.random.json
#   ✅ 62G-A-201  →  10 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/Random_Mask_Calculation/62G_A_201_masked_62G_A_201.meta.random.json
#   ✅ EAM-A-1  →  8 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/Random_Mask_Calculation/EAM_A_1_masked_EAM_A_1.meta.random.json
#   ✅ JQ1-A-1  →  11 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/Random_Mask_Calculation/JQ1_A_1_masked_JQ1_A_1.meta.random.json
#   ✅ JQ1-A-201  →  10 random indices  →  /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/Random_Mask_Calculation/JQ1_A_201_masked_JQ1_A_201.meta.random.json
#
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage3_analysis.py
# Out:
# ...
# STAGE 3: CHEMICAL SIMILARITY ANALYSIS
# ...
#
#   Before running the full analysis (which reads all Stage-2 prediction
#   files and Stage-1 JSONs), you can run a smoke test instead.
#
#   The smoke test:
#     • Does NOT need any Stage-1 or Stage-2 output files.
#     • Creates synthetic predictions for one ligand (aspirin) with
#       hard-coded SMILES (aspirin, ibuprofen, paracetamol, caffeine).
#     • Runs the full grid + histogram analysis with per_mask_count=True
#       and deduplication=True, then re-runs with per_mask_count=False.
#     • Saves all outputs to:
#         /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage3b_analysis/test
#       (this directory is wiped clean at the start of every test run).
#     • Prints PASS / FAIL for each assertion.
#
#   Run the smoke test? [y/N]: N
#
# ────────────────────────────────────────────────────────────
# STAGE 3 OPTIONS
# ────────────────────────────────────────────────────────────
#
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage5_chembl_matching.py
# Out:
# ...
# STAGE 5: ChEMBL BRD4 NEAREST-NEIGHBOUR MATCHING
# ...
#   Run the smoke test? [y/N]: N
#
# ────────────────────────────────────────────────────────────
# STAGE 5 OPTIONS
# ────────────────────────────────────────────────────────────
#
#   Cached ChEMBL data found at:
#     /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage5_chembl_matching/chembl_brd4_cache.csv
#   Use cached ChEMBL data (faster)? [Y/n]: Y
#
#   Pool choice — which generated molecules to analyse:
#     ia   : interaction-aware only  (Stage-1 masks)
#     rand : random only             (Stage-1.5 masks)
#     both : IA + random, deduplicated  [default]
#
#   Pool choice (ia / rand / both) [both]: both
#   Minimum heavy atoms for ChEMBL molecules (filters fragments) [7]:
#   Tanimoto similarity threshold T for 'close' decision (0.0–1.0) [0.4]:
#
#   Settings confirmed:
#     ChEMBL data    : cached  (/content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage5_chembl_matching/chembl_brd4_cache.csv)
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage4_1_brd4_matching.py
# Out:
# ────────────────────────────────────────────────────────────
# STAGE 4 OPTIONS
# ────────────────────────────────────────────────────────────
#
#   Pool choice — which generated molecules to analyse:
#     ia   : interaction-aware only  (Stage-1 masks)
#     rand : random only             (Stage-1.5 masks)
#     both : IA + random, deduplicated  [default]
#
#   Pool choice (ia / rand / both) [both]: ia
#   Minimum heavy atoms for BR4 ligands (filters solvents) [7]:
#   Similarity threshold T for 'close' decision (0.0–1.0) [0.4]: 0.42
#
#   Settings confirmed:
#     Pool              : ia
#     Min heavy atoms   : 7
#     Threshold T       : 0.42
# ────────────────────────────────────────────────────────────
#
# [14:07:57] SMILES Parse Error: syntax error while parsing: nan
# [14:07:57] SMILES Parse Error: check for mistakes around position 2:
# [14:07:57] nan
# [14:07:57] ~^
# [14:07:57] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# ...

# %%
##NO need to run
##!python /content/drive/MyDrive/GenAI4Drug/Code/stage5_1chembl_matching.py
# Out:
#   Use cached ChEMBL data? [Y/n]: Y
#   Pool choice (ia / rand / both) [both]: both
#   Minimum heavy atoms for ChEMBL molecules [7]:
#   Tanimoto similarity threshold T [0.4]: 0.42
#   Enter 1 (Stage 2), 2 (Stage 2.5), or 3 (Stage 2.7) [1]: 3

# %%
#check if GNINA is in full binary. If it has .ELFat end  everything is fine
# !head -c 4 /content/gnina | xxd
# Out:
# 00000000: 7f45 4c46                                .ELF

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage6_docking.py
# Out:
# ...
# STAGE 6: MOLECULAR DOCKING WITH GNINA
# ...
#
#   This stage docks all generated molecules (from Stage 2) into the BRD4
#   binding pocket using GNINA with autobox, then produces ranking plots.
#
#   GNINA binary : /content/drive/MyDrive/GenAI4Drug/gnina
#   (Auto-downloaded from GitHub v1.0.3 if not found.)
#
#   ⚠️  GNINA is Linux/x86_64 only. On macOS / Windows use WSL.
#   ⚠️  GPU (CUDA) is strongly recommended; CPU docking is very slow.
#   ⚠️  Already-docked molecules are skipped automatically (cached ✓).
#
#   Before running the full pipeline you can run a smoke test instead.
#   The smoke test uses a mock GNINA script — no binary, no GPU needed.
#   Writes to: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage6_docking/test
#   (wiped clean at the start of every test run).
#
#   Run the smoke test? [y/N]: n
#
# ────────────────────────────────────────────────────────────
# STAGE 6 OPTIONS
# ────────────────────────────────────────────────────────────
#
# ...

# %%
# !python /content/drive/MyDrive/GenAI4Drug/Code/stage8_1_novelty_potency_analysis.py
# Out:
# ...
# STAGE 8: NOVELTY vs POTENCY ANALYSIS
# ...
#
#   Reads docking_summary.csv from Stage 6 and produces:
#     • Scatter plots: Tanimoto (X) vs docking score (Y)
#         — one per ligand group + one combined
#     • Pareto front: non-dominated molecules (best novel + potent trade-offs)
#     • Hierarchical filter: CNNscore > T, Vinardo < T, sorted by CNNaffinity
#     • Top-10 PDF: Pareto-optimal molecules with drawing + all scores
#
#   config.STAGE8_INPUT_CSV = /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage6_docking/stage2/both/docking_summary.csv
#   config.STAGE8_DIR       = /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage8_analysis/ia
#
#   Smoke test uses synthetic data — no real docking required.
#
#   Run the smoke test? [y/N]: N
#   ⚠️  config.STAGE8_INPUT_CSV not found on disk: /content/drive/MyDrive/GenAI4Drug/Ishrak/Output/expo05/stage6_docking/stage2/both/docking_summary.csv
#
# ...

# %%
n
